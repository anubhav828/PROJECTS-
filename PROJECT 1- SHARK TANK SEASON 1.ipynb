# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#to see all the columns in the dataset 
pd.set_option('display.max_columns',None)

# %%
df=pd.read_csv('Shark.csv')

# %%
df
# Out:
#      episode_number  pitch_number           brand_name  \
# 0                 1             1  BluePine Industries
# 1                 1             2        Booz scooters
# 2                 1             3  Heart up my Sleeves
# 3                 2             4           Tagz Foods
# 4                 2             5       Head and Heart
# ..              ...           ...                  ...
# 112              34           113        Green Protein
# 113              34           114              On2Cook
# 114              35           115        Jain Shikanji
# 115              35           116                Woloo
# 116              35           117         Elcare India
#
#                                               idea  deal  pitcher_ask_amount  \
# 0                                     Frozen Momos     1                50.0
# 1    Renting e-bike for mobility in private spaces     1                40.0
# ...

# %%
df.isnull().sum()
# Out:
# episode_number           0
# pitch_number             0
# brand_name               0
# idea                     0
# deal                     0
# pitcher_ask_amount       0
# ask_equity               0
# ask_valuation            0
# deal_amount              0
# deal_equity              0
# deal_valuation           0
# ashneer_present          0
# anupam_present           0
# aman_present             0
# namita_present           0
# vineeta_present          0
# peyush_present           0
# ghazal_present           0
# ashneer_deal             0
# anupam_deal              0
# aman_deal                0
# namita_deal              0
# vineeta_deal             0
# peyush_deal              0
# ghazal_deal              0
# total_sharks_invested    0
# amount_per_shark         0
# equity_per_shark         0
# dtype: int64

# %%
df.shape
# Out:
# (117, 28)

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
#  ### HOW MANY DEALS DONE IN THE WHOLE SEASON

# %%
deal_done=df['deal'].value_counts()[0]
deal_notdone=df['deal'].value_counts()[1]
df['deal'].value_counts()
# Out:
# 1    65
# 0    52
# Name: deal, dtype: int64

# %%
print('Successfull deals of the first season is ~ ',deal_done)
print('Unsuccessfull deals of the second season is ~ ',deal_notdone)
# Out:
# Successfull deals of the first season is ~  52
# Unsuccessfull deals of the second season is ~  65

# %% [markdown]
# ##### display this visualization over a pie chart

# %%
df['deal'].value_counts().plot(autopct='%.2f%%',kind='pie')
# Out:
# <AxesSubplot:ylabel='deal'>

# %% [markdown]
# ## most dealing episodes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   episode_number         117 non-null    int64
#  1   pitch_number           117 non-null    int64
#  2   brand_name             117 non-null    object
#  3   idea                   117 non-null    object
#  4   deal                   117 non-null    int64
#  5   pitcher_ask_amount     117 non-null    float64
#  6   ask_equity             117 non-null    float64
#  7   ask_valuation          117 non-null    float64
#  8   deal_amount            117 non-null    float64
#  9   deal_equity            117 non-null    float64
#  10  deal_valuation         117 non-null    float64
#  11  ashneer_present        117 non-null    int64
#  12  anupam_present         117 non-null    int64
#  13  aman_present           117 non-null    int64
# ...

# %%
df.groupby(['episode_number'])['deal'].sum().sort_values(ascending=False).reset_index()
# Out:
#     episode_number  deal
# 0                1     3
# 1               15     3
# 2               21     3
# 3               33     3
# 4                8     3
# 5               10     3
# 6               17     3
# 7               16     3
# 8               13     3
# 9               25     2
# 10              24     2
# 11              28     2
# 12              20     2
# 13              26     2
# 14              27     2
# 15              12     2
# 16              11     2
# 17               9     2
# 18               6     2
# 19               4     2
# 20               3     2
# 21              31     1
# 22              30     1
# 23              29     1
# 24              34     1
# 25              32     1
# 26              18     1
# 27              23     1
# 28              22     1
# 29              19     1
# 30               2     1
# 31              14     1
# 32               7     1
# 33               5     1
# 34              35     1

# %%
sns.catplot(x='deal',y='episode_number',data=df)

# %% [markdown]
# ## most expensive dealing episode

# %%
df.groupby(['episode_number'])['deal_amount'].sum().sort_values(ascending=False).reset_index()
# Out:
#     episode_number  deal_amount
# 0               17    280.00000
# 1               13    255.00000
# 2               16    170.00000
# 3               21    160.00000
# 4               28    150.00000
# 5               25    150.00000
# 6                6    150.00000
# 7               20    140.00000
# 8                1    140.00000
# 9                8    136.00000
# 10              15    125.00005
# 11               4    125.00000
# 12              12    115.00000
# 13              26    115.00000
# 14              33    110.00000
# 15              27    100.00101
# 16               9    100.00000
# 17              14    100.00000
# 18               7    100.00000
# 19               5    100.00000
# 20               3     95.00000
# 21              10     85.00000
# 22              11     80.00000
# 23              30     80.00000
# 24              29     75.00000
# 25              31     75.00000
# 26               2     70.00000
# 27              24     60.00000
# ...

# %%
plt.figure(figsize=(10,6),dpi=200)
plt.bar(A['episode_number'],A['deal_amount'])
plt.xticks(df['episode_number'].unique(),rotation=90,fontsize=8)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [58], in <cell line: 2>()
#       1 plt.figure(figsize=(10,6),dpi=200)
# ----> 2 plt.bar(A['episode_number'],A['deal_amount'])
#       3 plt.xticks(df['episode_number'].unique(),rotation=90,fontsize=8)
#       4 plt.show()
#
# NameError: name 'A' is not defined

# %%
df.info()

# %%
df[df['total_sharks_invested']==5]
# Out:
#     episode_number  pitch_number             brand_name                 idea  \
# 15               6            16            Skippi Pops             Ice-Pops
# 49              17            50  Find Your Kicks India       Sneaker Resale
# 63              20            64               IN A CAN        Can Cocktails
# 79              25            80    Sunfox Technologies  Portable ECG Device
#
#     deal  pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  \
# 15     1                45.0         5.0          900.0        100.0
# 49     1                50.0        10.0          500.0         50.0
# 63     1                50.0         2.0         2500.0        100.0
# 79     1               100.0         2.0         5000.0        100.0
#
#     deal_equity  deal_valuation  ashneer_present  anupam_present  \
# 15         15.0          666.67                1               1
# 49         25.0          200.00                1               1
# ...

# %%
df['total_sharks_invested'].value_counts()
#here 0 represents that 52 ideas in which none of the sharks has invested
#here 1 represents that atleast 1 shark has invested in 22 ideas together
#here 2 represents that 2 sharks has invested in 20 ideas together
#here 3 represents that 3 sharks has invesetd in 14 ideas together
#here 4 represents that 4 sharks has invested in 5 ideas together
#here 4 represents that 5 sharks together has invested in the startup
# Out:
# 0    52
# 1    22
# 2    20
# 3    14
# 4     5
# 5     4
# Name: total_sharks_invested, dtype: int64

# %%
#now my question is that i want to see the ideas in which 5 sharks has invested together.
df[df['total_sharks_invested']==5]
df[df['total_sharks_invested']==4]
# Out:
#      episode_number  pitch_number          brand_name  \
# 38               13            39     The Yarn Bazaar
# 58               19            59             WeSTOCK
# 85               27            86  Watt Technovations
# 110              34           111  Nomad Food Project
# 114              35           115       Jain Shikanji
#
#                                idea  deal  pitcher_ask_amount  ask_equity  \
# 38                 Yarn-Trading App     1            50.00000         2.0
# 58   Livestock health monitoring AI     1            50.00000         5.0
# 85              Ventilated PPE Kits     1             0.00101        10.0
# 110                      Bacon Jams     1            40.00000        10.0
# 114                        Lemonade     1            40.00000         8.0
#
#      ask_valuation  deal_amount  deal_equity  deal_valuation  ashneer_present  \
# 38         2500.00    100.00000         10.0         1000.00                1
# ...

# %%
plt.figure(figsize=(10,6))
plt.title("Total Sharks In")
plt.bar(df['episode_number'],df['total_sharks_invested'])
plt.xticks(df['episode_number'].unique(),rotation=30);

# %% [markdown]
# ### DEAL WITH NO BARGAIN

# %%
# df.info()
df[df['ask_valuation']==df['deal_valuation']]
# Out:
#     episode_number  pitch_number    brand_name                 idea  deal  \
# 21               8            22  Beyond Snack  Kerala Banana Chips     1
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 21                50.0         2.5         2000.0         50.0          2.5
#
#     deal_valuation  ashneer_present  anupam_present  aman_present  \
# 21          2000.0                1               1             1
#
#     namita_present  vineeta_present  peyush_present  ghazal_present  \
# 21               1                0               1               0
#
#     ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 21             1            0          1            0             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 21            0            0                      2              25.0
#
#     equity_per_shark
# 21              1.25

# %% [markdown]
# ### NO OF SHARKS INVESTED AS PER THE IDEAS

# %%
sns.countplot(x=df['total_sharks_invested'])
plt.title('no of sharks invested',fontsize=15)
plt.show()

# %% [markdown]
# ## ASHNEER DEALS

# %%
df.columns
ash_grover=df[df['ashneer_deal']==1]#represents all the data that ashneer has invested
ash_grover
df[(df['ashneer_deal']==1) & (df['total_sharks_invested']==1)]
# Out:
#     episode_number  pitch_number     brand_name                       idea  \
# 3                2             4     Tagz Foods       Healthy Potato Chips
# 23               8            24  Motion Breeze  Smart Electric Motorcycle
# 55              18            56           Otua      Electric Auto Vehicle
#
#     deal  pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  \
# 3      1                70.0         1.0         7000.0         70.0
# 23     1                30.0         3.0         1000.0         30.0
# 55     1               100.0         1.0        10000.0          1.0
#
#     deal_equity  deal_valuation  ashneer_present  anupam_present  \
# 3          2.75         2545.45                1               1
# 23         6.00          500.00                1               1
# 55         1.00          100.00                1               1
#
#     aman_present  namita_present  vineeta_present  peyush_present  \
# ...

# %% [markdown]
# #### TO CHECK THAT DEAL IN WHICH ONLY ASHNEER HAS INVESTED  (without applying any function)

# %%
df[(df['ashneer_deal']==1) & (df['total_sharks_invested']==1)]
# df[(df['ashneer_deal']==1) & (df['total_sharks_invested']==1)]
# Out:
#     episode_number  pitch_number     brand_name                       idea  \
# 3                2             4     Tagz Foods       Healthy Potato Chips
# 23               8            24  Motion Breeze  Smart Electric Motorcycle
# 55              18            56           Otua      Electric Auto Vehicle
#
#     deal  pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  \
# 3      1                70.0         1.0         7000.0         70.0
# 23     1                30.0         3.0         1000.0         30.0
# 55     1               100.0         1.0        10000.0          1.0
#
#     deal_equity  deal_valuation  ashneer_present  anupam_present  \
# 3          2.75         2545.45                1               1
# 23         6.00          500.00                1               1
# 55         1.00          100.00                1               1
#
#     aman_present  namita_present  vineeta_present  peyush_present  \
# ...

# %%
def sharks(data):
    list=['anupam_deal','aman_deal','namita_deal','vineeta_deal','peyush_deal','ghazal_deal','ashneer_deal']
    for i in list:
        deal= data[['amount_per_shark','equity_per_shark']][data[i]==1]
        print("\n{} deals with {} ".format(len(deal),i[:-5]))
        print('deal')

# %%
sharks(ash_grover)
# Out:
# 8 deals with anupam
# deal
#
# 11 deals with aman
# deal
#
# 6 deals with namita
# deal
#
# 6 deals with vineeta
# deal
#
# 9 deals with peyush
# deal
#
# 1 deals with ghazal
# deal
#
# 21 deals with ashneer
# deal

# %% [markdown]
# ## ASHNEER'S TOTAL EQUITY ACHIEVED AS PER HIS TOTAL INVESTMENT

# %%
eqt=df.groupby(['ashneer_deal'])['equity_per_shark'].sum()[1]
amt=df.groupby(['ashneer_deal'])['amount_per_shark'].sum()[1]
print('Total equity earned by Ashneer"s investment is about ',eqt,'%')
print("Total amount invested by Ashneer is about ",amt,'lakhs' )

# %% [markdown]
# ### ASHNEER'S HIGHEST INVESTMENT ON WHICH IDEA?

# %%
ash_grover[ash_grover['amount_per_shark']==ash_grover['amount_per_shark'].max()]

# %% [markdown]
# # ANUPAM DEALS

# %%
df.columns
anu_pam=df[df['anupam_deal']==1]
anu_pam

# %% [markdown]
# ### ANUPAM'S HIGHEST INVESTMENTS

# %%
anu_pam[anu_pam['amount_per_shark']==anu_pam['amount_per_shark'].max()]

# %% [markdown]
# ### ANUPAM'S  TOTAL EQUITY EARNED AND HIS TOTAL INVESTMENT DONE ON SHARKS

# %%
eqt1=df.groupby(['anupam_deal'])['deal_equity'].sum()[1]
amt1=df.groupby(['anupam_deal'])['deal_amount'].sum()[1]
print("total equity achieved by ANUPAM is ",eqt1,"% ")
print("total amount invested by ANUPAM is",amt1,"lakhs")

# %% [markdown]
# ## VINEETA"S DEALS

# %%
vineeta=df[df['vineeta_deal']==1]
# df.columns

# %% [markdown]
# ### VINEETA'S HIGHEST INVESTMENT

# %%
### VINEETA'S HIGHEST INVESTMENT
vineeta[vineeta['amount_per_shark']==vineeta['amount_per_shark'].max()]

# %% [markdown]
# ## VINEETA'S HIGHEST EARNED EQUITY AS PER THE INVESTEMENT MADE BY HER.

# %%
eqt2=df.groupby(['vineeta_deal'])['deal_equity'].sum()[1]
amt2=df.groupby(['vineeta_deal'])['deal_amount'].sum()[1]
print("Total equity earned by by Vineeta is ", eqt2 ,'%')
print("Total amount invested by Vineeta is ", amt2,"lakhs")

# %%
df.columns

# %% [markdown]
# ## AMAN DEALS

# %%
aman=df[df['aman_deal']==1]
aman

# %% [markdown]
# ### HIGHEST DEAL OF AMAN

# %%
aman[aman['amount_per_shark']==aman['amount_per_shark'].max()]

# %% [markdown]
# ### AMAN TOTAL EQUITY ACHIEVED AND TOTAL AMOUNT SPEND.

# %%
eqt3=df.groupby(['aman_deal'])['deal_equity'].sum()[1]
amt3=df.groupby(['aman_deal'])['deal_amount'].sum()[1]
print('Total equity achieved by Aman is ',eqt3,'%')
print('Total Amount achieved by Aman in the 1st season ',amt3,'lakhs')

# %%
df.columns

# %% [markdown]
# ## PEYUSH TOTAL DEALS

# %%
peyush=df[df['peyush_deal']==1]

# %% [markdown]
# ### PEYUSH HIGHEST DEAL

# %%
peyush[peyush['amount_per_shark']==peyush['amount_per_shark'].max()]

# %% [markdown]
# ### TOTAL EQUITY ACHIEVED AND THE AMOUNT INVESTED BY PEYUSH

# %%
eqt4=df.groupby(['peyush_deal'])['deal_equity'].sum()[1]
amt4=df.groupby(['peyush_deal'])['deal_amount'].sum()[1]
print("Total equity achieved by peyush is ",eqt4,'%')
print("Total amount invested by peyush is ",amt4,'%')
# Out:
# Total equity achieved by peyush is  499.3 %
# Total amount invested by peyush is  1556.00101 %

# %% [markdown]
# # NAMITA TOTAL DEALS

# %%
namita=df[df['namita_deal']==1]

# %% [markdown]
# ## namita's highest deal in season 1

# %%
namita[namita['amount_per_shark']==namita['amount_per_shark'].max()]
# Out:
#     episode_number  pitch_number      brand_name                idea  deal  \
# 33              12            34  Auli Lifestyle  Ayurvedic Products     1
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 33                75.0         4.0         1875.0         75.0         15.0
#
#     deal_valuation  ashneer_present  anupam_present  aman_present  \
# 33           500.0                1               1             1
#
#     namita_present  vineeta_present  peyush_present  ghazal_present  \
# 33               1                0               1               0
#
#     ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 33             0            0          0            1             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 33            0            0                      1              75.0
#
#     equity_per_shark
# 33              15.0

# %% [markdown]
# ## namita's total equity and total amount invested

# %%
eqt5=df.groupby(['namita_deal'])['deal_equity'].sum()[1]
amt5=df.groupby(['namita_deal'])['deal_amount'].sum()[1]
print("Total equity achieved by namita is ",eqt5,'%')
print("Total amount invested by namita to achieve this equity is ",amt5,'lakhs')
# Out:
# Total equity achieved by namita is  278.5 %
# Total amount invested by namita to achieve this equity is  1445.00106 lakhs

# %% [markdown]
# # NUMBER OF SHARKS INVESTMENT IN TEAMS

# %%
#PART 1
q=df[df['total_sharks_invested']>1]
q['total_sharks_invested'].value_counts().sum()
# Out:
# 43

# %%
#PART 2
teamup=df[df['total_sharks_invested']>1]
plt.figure(figsize=(7,7))
plt.hist(teamup.total_sharks_invested)
plt.yticks(q['total_sharks_invested'].value_counts().values);
plt.title('visualization of number of sharks teamed up')
plt.xlabel("no of sharks ")
plt.ylabel("no of investments")
# Out:
# Text(0, 0.5, 'no of investments')

# %%
#PART 3
L=[]
for i in range(1,44):
    L.append(8)
print(L)
# Out:
# [8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]

# %%
plt.figure(dpi=200)
plt.scatter(teamup['brand_name'],teamup['total_sharks_invested'],s=L);
plt.xticks(rotation=90,fontsize=8);

# %% [markdown]
# # TOTAL AMOUNT INVESTED BY SHARKS IN DIFFERENT COMPANIES
#
# ### here I am assigning the alphabets as per the investment made by the sharks in different companies
# #### 'a' represents the deals of ashneer ,  'b' represents the deals of anupam , 'c' represents the deals of aman, 'd' represents the deals of namita, 'e' represents the deals of vineeta,  'f' represents the deals of peyush ,  'g' represents the deals of ghazal.
# #### 't' represents the investments of ashneer ,  'u' represents the investements of anupam , 'v' represents the investments of aman, 'w' represents the investments of namita, 'x' represents the investments of vineeta,  'y' represents the investments of peyush ,  'z' represents the investments of ghazal.

# %%
a=df[df['ashneer_deal']==1]
aa=list(a.amount_per_shark)
aa
t=0
for i in aa:
    t=t+i
b=df[df['anupam_deal']==1]
ba=list(b.amount_per_shark)
u=0
for i in ba:
    u=u+i
c=df[df['aman_deal']==1]
ca=list(c.amount_per_shark)
v=0
for i in ca:
    v=v+i
d=df[df['namita_deal']==1]
da=list(d.amount_per_shark)
w=0
for i in da:
    w=w+i
e=df[df['vineeta_deal']==1]
ea=list(e.amount_per_shark)
x=0
for i in ea:
    x=x+i
f=df[df['peyush_deal']==1]
fa=list(f.amount_per_shark)
y=0
for i in fa:
    y=y+i
g=df[df['ghazal_deal']==1]
ga=list(g.amount_per_shark)
z=0
for i in ga:
    z=z+i
