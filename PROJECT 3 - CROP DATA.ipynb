# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## instructions

# %%
df=pd.read_csv("Crop .csv")

# %%
df
# Out:
#        Unnamed: 0      State_Name District_Name  Crop_Year       Season  \
# 0               0       Karnataka         UDUPI       2005  Rabi
# 1               1  Madhya Pradesh       GWALIOR       2003  Whole Year
# 2               2  Andhra Pradesh      CHITTOOR       2010  Rabi
# 3               3  Andhra Pradesh       KRISHNA       2014  Rabi
# 4               4   Uttar Pradesh     SULTANPUR       2011  Rabi
# ...           ...             ...           ...        ...          ...
# 73822       73822   Uttar Pradesh     SULTANPUR       2001  Rabi
# 73823       73823    Chhattisgarh          DURG       2014  Rabi
# 73824       73824   Uttar Pradesh    RAE BARELI       2010  Summer
# 73825       73825           Assam        KAMRUP       1998  Rabi
# 73826       73826  Andhra Pradesh        GUNTUR       2005  Rabi
#
#                     Crop      Area  Production
# 0             Horse-gram    1122.0       836.0
# 1                Brinjal     194.0         0.0
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       1148
# dtype: int64

# %%
df=df.dropna(axis=0)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %% [markdown]
# ### Q1.Which of these crops are produced during the Summer season? (select option with all that apply) a. Arecanut, Arhar/Tur, Bajra, Castor seedb. Paddy, Maize, Moong (Green Gram), Onion, Sunflowerc. Banana, Coriander, Gram, Rapeseed & Mustardd. Rice, Sugarcane, Paddy, Tomato

# %%
df["Season"].unique()
# Out:
# array(['Rabi       ', 'Whole Year ', 'Kharif     ', 'Autumn     ',
#        'Winter     ', 'Summer     '], dtype=object)

# %%
summer=df[df["Season"]=='Summer     ']

# %%
summer["Crop"].unique()
# Out:
# array(['Groundnut', 'Maize', 'Rice', 'Sesamum', 'Wheat', 'Onion', 'Urad',
#        'Peas & beans (Pulses)', 'Sunflower', 'Ragi', 'Bajra',
#        'Moong(Green Gram)', 'Cotton(lint)', 'Jowar', 'Cowpea(Lobia)',
#        'Tobacco', 'Horse-gram', 'Dry chillies', 'Paddy', 'Turmeric',
#        'Arhar/Tur', 'Banana', 'Potato', 'Dry ginger', 'Brinjal',
#        'Sugarcane', 'Other  Rabi pulses', 'Small millets',
#        'Total foodgrain'], dtype=object)

# %%
#we are comparing to do it ,with the help of question.

# %% [markdown]
# #### Q2. During which year did Haryana have the highest crop production?

# %%
df["Crop_Year"].unique()
# Out:
# array([2005, 2003, 2010, 2014, 2011, 2002, 2006, 2001, 2009, 2008, 2013,
#        1999, 1998, 1997, 2004, 2012, 2007, 2000, 2015], dtype=int64)

# %%
df["State_Name"].unique()
# Out:
# array(['Karnataka', 'Madhya Pradesh', 'Andhra Pradesh', 'Uttar Pradesh',
#        'Rajasthan', 'Assam', 'Bihar', 'Odisha', 'Chhattisgarh', 'Kerala',
#        'Telangana ', 'Maharashtra', 'Nagaland', 'Puducherry', 'Gujarat',
#        'Himachal Pradesh', 'Tamil Nadu', 'West Bengal',
#        'Jammu and Kashmir ', 'Arunachal Pradesh', 'Uttarakhand',
#        'Haryana', 'Mizoram', 'Manipur', 'Punjab', 'Jharkhand',
#        'Meghalaya', 'Andaman and Nicobar Islands', 'Sikkim', 'Tripura',
#        'Dadra and Nagar Haveli', 'Goa', 'Chandigarh'], dtype=object)

# %%
h=df[df["State_Name"]=="Haryana"]

# %%
h.groupby(["Crop_Year"])["Production"].sum().sort_values(ascending=False)
# Out:
# Crop_Year
# 2008    9647100.0
# 2005    9328300.0
# 2011    9021300.0
# 2003    8437562.0
# 2012    7996416.0
# 2002    7837700.0
# 2004    7523400.0
# 2007    7323500.0
# 1999    7188901.0
# 2001    7009900.0
# 1998    6653600.0
# 2006    6566600.0
# 2000    5872800.0
# 2010    5548900.0
# 2009    5214480.0
# 1997    3376800.0
# Name: Production, dtype: float64

# %%
# so here is the answer for this question as the production made in 2008 year was the biggest stated 9447100.0

# %% [markdown]
# ## Q.similar to question number 2
# ### in which year did Karnataka have the highest production

# %%
k=df[df["State_Name"]=="Karnataka"]

# %%
k.groupby(["Crop_Year"])["Production"].sum().sort_values().tail(1)
# Out:
# Crop_Year
# 2011    30415758.1
# Name: Production, dtype: float64

# %%
O=df[df["State_Name"]=="Odisha"]

# %%
O.groupby(["Crop_Year"])["Production"].sum().sort_values(ascending=True)
# Out:
# Crop_Year
# 2002    1483577.1
# 2007    1798987.0
# 2015    1853312.3
# 2005    1974365.8
# 2008    2049737.5
# 2000    2213610.0
# 1997    2255460.0
# 1998    2275405.0
# 2011    2292102.1
# 2006    2350041.1
# 2009    2418953.1
# 2012    2454382.1
# 2003    2502831.6
# 2001    2652445.5
# 2013    2723819.4
# 2010    2791016.5
# 2004    2883004.2
# 2014    3189411.4
# 1999    3470600.0
# Name: Production, dtype: float64

# %%
hh=df[df["State_Name"]=="Haryana"]

# %%
hh.groupby(["Crop_Year"])["Production"].sum().sort_values(ascending=False)
# Out:
# Crop_Year
# 2008    9647100.0
# 2005    9328300.0
# 2011    9021300.0
# 2003    8437562.0
# 2012    7996416.0
# 2002    7837700.0
# 2004    7523400.0
# 2007    7323500.0
# 1999    7188901.0
# 2001    7009900.0
# 1998    6653600.0
# 2006    6566600.0
# 2000    5872800.0
# 2010    5548900.0
# 2009    5214480.0
# 1997    3376800.0
# Name: Production, dtype: float64

# %% [markdown]
# ## Q11. Which is the only crop that has the highest production during autumn, summer, and winter?
# #### Ans. is rice

# %%
autumn=df[df["Season"]=='Autumn     ']

# %%
summer=df[df["Season"]=='Summer     ']

# %%
winter=df[df["Season"]=='Winter     ']

# %%
autumn.groupby(["Crop"])["Production"].sum().sort_values(ascending=False)
# Out:
# Crop
# Rice                     14820963.70
# Maize                     3089100.78
# Paddy                      521140.00
# Jute                       155210.90
# Ragi                       121504.38
# Groundnut                   97968.50
# Urad                        39608.00
# Moong(Green Gram)           24799.50
# Dry chillies                10513.00
# Sesamum                      5302.10
# Banana                       3980.00
# Arhar/Tur                    3937.00
# Sugarcane                    1291.20
# Small millets                 595.00
# Dry ginger                    360.00
# Tapioca                       130.00
# Potato                        100.00
# Peas & beans (Pulses)          50.00
# Onion                          20.00
# Turmeric                       20.00
# Name: Production, dtype: float64

# %%
summer.groupby(["Crop"])["Production"].sum().sort_values(ascending=False)
# Out:
# Crop
# Rice                     38709052.2
# Maize                     4840564.0
# Groundnut                 2083123.3
# Bajra                     1779222.0
# Paddy                     1638436.0
# Moong(Green Gram)          735738.3
# Sesamum                    618864.8
# Onion                      596379.0
# Banana                     272080.0
# Sunflower                  170886.0
# Potato                     168904.0
# Urad                       107210.8
# Ragi                       103252.8
# Jowar                       59373.0
# Dry chillies                54145.0
# Wheat                       17009.9
# Cotton(lint)                10622.0
# Peas & beans (Pulses)       10066.0
# Tobacco                      5318.0
# Sugarcane                    4570.0
# Arhar/Tur                    3198.0
# Cowpea(Lobia)                2511.0
# Dry ginger                    860.0
# Total foodgrain               617.0
# Brinjal                       552.0
# Horse-gram                    287.6
# ...

# %%
winter.groupby(["Crop"])["Production"].sum().sort_values(ascending=False)
# Out:
# Crop
# Rice                     1.113293e+08
# Potato                   8.277893e+06
# Sugarcane                4.839051e+06
# Paddy                    4.622613e+06
# Horse-gram               8.732610e+04
# Ragi                     8.064870e+04
# Urad                     7.479070e+04
# Moong(Green Gram)        6.656960e+04
# Sesamum                  3.270780e+04
# Arhar/Tur                1.260100e+04
# Groundnut                1.229040e+04
# Rapeseed &Mustard        9.776100e+03
# Banana                   8.770000e+03
# Maize                    3.129800e+03
# Wheat                    1.652000e+03
# Dry chillies             7.000000e+02
# Gram                     5.740000e+02
# Niger seed               3.015000e+02
# Peas & beans (Pulses)    1.100000e+02
# Sannhamp                 7.300000e+01
# Dry ginger               4.000000e+01
# Sweet potato             3.000000e+01
# Onion                    2.000000e+01
# Name: Production, dtype: float64

# %%
df["Season"].unique()
# Out:
# array(['Rabi       ', 'Whole Year ', 'Kharif     ', 'Autumn     ',
#        'Winter     ', 'Summer     '], dtype=object)

# %%
df
# Out:
#        Unnamed: 0      State_Name District_Name  Crop_Year       Season  \
# 0               0       Karnataka         UDUPI       2005  Rabi
# 1               1  Madhya Pradesh       GWALIOR       2003  Whole Year
# 2               2  Andhra Pradesh      CHITTOOR       2010  Rabi
# 3               3  Andhra Pradesh       KRISHNA       2014  Rabi
# 4               4   Uttar Pradesh     SULTANPUR       2011  Rabi
# ...           ...             ...           ...        ...          ...
# 73822       73822   Uttar Pradesh     SULTANPUR       2001  Rabi
# 73823       73823    Chhattisgarh          DURG       2014  Rabi
# 73824       73824   Uttar Pradesh    RAE BARELI       2010  Summer
# 73825       73825           Assam        KAMRUP       1998  Rabi
# 73826       73826  Andhra Pradesh        GUNTUR       2005  Rabi
#
#                     Crop      Area  Production
# 0             Horse-gram    1122.0       836.0
# 1                Brinjal     194.0         0.0
# ...

# %%
df["Crop"]==""
# Out:
# 0               Horse-gram
# 1                  Brinjal
# 2                  Sesamum
# 3                   Tomato
# 4                Coriander
#                ...
# 73822    Rapeseed &Mustard
# 73823                Wheat
# 73824    Moong(Green Gram)
# 73825                Wheat
# 73826                 Urad
# Name: Crop, Length: 72679, dtype: object

# %% [markdown]
# ### Q8. Which of the following statements is true? (Select all that applies)
#
# ##### a. The overall production during the Kharif season is 2,029,970,000 (approx.)
# ##### b. The overall production during the Summer season is 51,992,900 (approx.)
#
# ##### c. The overall production during the Autumn season is 14,413,770 (approx.)
# ##### d. The overall production during the Kharif season is 1,282,056,700 (approx.)

# %%
df[df["Production"]=="Season"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, State_Name, District_Name, Crop_Year, Season, Crop, Area, Production]
# Index: []

# %%
df["Crop"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0               Horse-gram
# 1                  Brinjal
# 2                  Sesamum
# 3                   Tomato
# 4                Coriander
#                ...
# 73822    Rapeseed &Mustard
# 73823                Wheat
# 73824    Moong(Green Gram)
# 73825                Wheat
# 73826                 Urad
# Name: Crop, Length: 72679, dtype: object>

# %%
kharif=df[df["Season"]=='Kharif     ']

# %%
kharif["Production"].sum()
# Out:
# 'Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif     Kharif 
# ...

# %%
df.groupby(["Crop_Year"])["Production"].sum()
# Out:
# Crop_Year
# Kharif         Kharif     Kharif     Kharif     Kharif     Kh...
# Name: Production, dtype: object

# %%
df["Crop_Year"]='Kharif     '
# Out:
# C:\Users\ANUBHAV GUPTA\AppData\Local\Temp\ipykernel_4568\2725325481.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Crop_Year"]='Kharif     '

# %%
kharif=df[df["Production"]=='Kharif     ']

# %%
df[df["Crop_Year"]=='Kharif     ']
# Out:
#        Unnamed: 0      State_Name District_Name    Crop_Year       Season  \
# 0               0       Karnataka         UDUPI  Kharif       Kharif
# 1               1  Madhya Pradesh       GWALIOR  Kharif       Kharif
# 2               2  Andhra Pradesh      CHITTOOR  Kharif       Kharif
# 3               3  Andhra Pradesh       KRISHNA  Kharif       Kharif
# 4               4   Uttar Pradesh     SULTANPUR  Kharif       Kharif
# ...           ...             ...           ...          ...          ...
# 73822       73822   Uttar Pradesh     SULTANPUR  Kharif       Kharif
# 73823       73823    Chhattisgarh          DURG  Kharif       Kharif
# 73824       73824   Uttar Pradesh    RAE BARELI  Kharif       Kharif
# 73825       73825           Assam        KAMRUP  Kharif       Kharif
# 73826       73826  Andhra Pradesh        GUNTUR  Kharif       Kharif
#
#                     Crop      Area   Production
# 0             Horse-gram    1122.0  Kharif
# ...

# %%
df
# Out:
#        Unnamed: 0      State_Name District_Name    Crop_Year       Season  \
# 0               0       Karnataka         UDUPI  Kharif       Kharif
# 1               1  Madhya Pradesh       GWALIOR  Kharif       Kharif
# 2               2  Andhra Pradesh      CHITTOOR  Kharif       Kharif
# 3               3  Andhra Pradesh       KRISHNA  Kharif       Kharif
# 4               4   Uttar Pradesh     SULTANPUR  Kharif       Kharif
# ...           ...             ...           ...          ...          ...
# 73822       73822   Uttar Pradesh     SULTANPUR  Kharif       Kharif
# 73823       73823    Chhattisgarh          DURG  Kharif       Kharif
# 73824       73824   Uttar Pradesh    RAE BARELI  Kharif       Kharif
# 73825       73825           Assam        KAMRUP  Kharif       Kharif
# 73826       73826  Andhra Pradesh        GUNTUR  Kharif       Kharif
#
#                     Crop      Area   Production
# 0             Horse-gram    1122.0  Kharif
# ...

# %%
df["State_Name"].unique()
# Out:
# array(['Karnataka', 'Madhya Pradesh', 'Andhra Pradesh', 'Uttar Pradesh',
#        'Rajasthan', 'Assam', 'Bihar', 'Odisha', 'Chhattisgarh', 'Kerala',
#        'Telangana ', 'Maharashtra', 'Nagaland', 'Puducherry', 'Gujarat',
#        'Himachal Pradesh', 'Tamil Nadu', 'West Bengal',
#        'Jammu and Kashmir ', 'Arunachal Pradesh', 'Uttarakhand',
#        'Haryana', 'Mizoram', 'Manipur', 'Punjab', 'Jharkhand',
#        'Meghalaya', 'Andaman and Nicobar Islands', 'Sikkim', 'Tripura',
#        'Dadra and Nagar Haveli', 'Goa', 'Chandigarh'], dtype=object)

# %%
df[df["State_Name"]=="ab"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, State_Name, District_Name, Crop_Year, Season, Crop, Area, Production]
# Index: []

# %%
ab=df["Production"].min()

# %%
df["Crop_Year"].min()
# Out:
# 'Kharif     '

# %%
df.groupby(["State_Name"])("Production").sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [104], in <cell line: 1>()
# ----> 1 df.groupby(["State_Name"])("Production").sum()
#
# TypeError: 'DataFrameGroupBy' object is not callable
